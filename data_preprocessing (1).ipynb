# %% [markdown]
# # Install Libraries

# %%
# %pip install scikit-learn xgboost fastapi uvicorn shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install xgboost
# Out:
# Access is denied.

# %%
import sys 
# !{sys.executable} -mpip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd 
import numpy as np 
import sklearn 
from xgboost import XGBClassifier
import fastapi
import uvicorn 
import joblib
import shap
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
import os  
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Data Cleaning.ipynb', 'data_preprocessing (1).ipynb', 'EDA.ipynb', 'Feature Engineering & Predictive Modeling.ipynb', 'LTV Calculation & API Development.ipynb', 'Telco-Customer-Churn.csv']

# %%
def load_data(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    print("Data loaded successfully")
    print("Shape:", df.shape)
    return df

# %%
def basic_cleaning(df: pd.DataFrame) -> pd.DataFrame:
    
    # 1. Drop unnecessary column
    if 'customerID' in df.columns:
        df.drop('customerID', axis=1, inplace=True)

    # 2. Fix TotalCharges (it is string sometimes)
    if 'TotalCharges' in df.columns:
        df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

    # 3. Handle missing values
    df.fillna(df.median(numeric_only=True), inplace=True)

    print("Basic cleaning done")
    return df

# %%
def data_overview(df: pd.DataFrame):
    print("\nFirst 5 rows:")
    print(df.head())

    print("\nInfo:")
    print(df.info())

    print("\nMissing values:")
    print(df.isnull().sum())

# %%
if __name__ == "__main__":
    path = r"C:\Users\Asus\OneDrive\Desktop\Zaalima Project\project 1\Telco-Customer-Churn.csv" 
    
    df = load_data(path)
    df = basic_cleaning(df)
    data_overview(df)
# Out:
# Data loaded successfully
# Shape: (7043, 21)
# Basic cleaning done
#
# First 5 rows:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...
